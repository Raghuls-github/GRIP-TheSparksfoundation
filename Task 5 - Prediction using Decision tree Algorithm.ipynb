# %% [markdown]
# ### Author: Raghul V

# %% [markdown]
# #### Task 3: Prediction using Decision Tree Algorithm

# %% [markdown]
# ### Graduate Rotational Internship Program @ THE SPARKS FOUNDATION

# %% [markdown]
# Decision Tree Algorithm can perform both classification and regression tasks, and even can carryout multioutput tasks.
#  - Creating a decision tree classifier for the given 'Iris' dataset.
#  - Visualizing it graphically.
#
# The aim of this task is to predict the right class from the new data feeds in the classifier.

# %% [markdown]
# ### Technical Requirements

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in g:\anaconda\lib\site-packages (0.16)

# %%
# !pip install pydot-ng
# Out:
# Requirement already satisfied: pydot-ng in g:\anaconda\lib\site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=2.0.1 in g:\anaconda\lib\site-packages (from pydot-ng) (2.4.7)

# %%
# Importing the required Libraries

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
import sklearn.metrics as sm

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import pydot
from IPython.display import Image
print("Libraries Imported")
# Out:
# Libraries Imported

# %% [markdown]
# ### Loading the 'Iris' Dataset

# %%
# Loading 'Iris'
iris = load_iris()
X=iris.data[:,:] 
y=iris.target
print("Affirmative")
# Out:
# Affirmative

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Input data 

data=pd.DataFrame(iris['data'],columns=["Petal length","Petal Width","Sepal Length","Sepal Width"])
data['Species']=iris['target']
data['Species']=data['Species'].apply(lambda x: iris['target_names'][x])

data.head()
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#        Petal length  Petal Width  Sepal Length  Sepal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Visualizing the data and comparing various features

# %%
# Input data for visualization
sns.pairplot(data)

# %%
# Scatter plot of data based on Sepal Length and Width features
sns.FacetGrid(data,hue='Species').map(plt.scatter,'Sepal Length','Sepal Width').add_legend()
plt.show()

# Scatter plot of data based on Petal Length and Width features
sns.FacetGrid(data,hue='Species').map(plt.scatter,'Petal length','Petal Width').add_legend()
plt.show()

# %% [markdown]
# ### Model Training (Decision Tree)

# %%
# Model Training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1) 
tree_classifier = DecisionTreeClassifier()
tree_classifier.fit(X_train,y_train)
print("Training Completed.")
y_pred = tree_classifier.predict(X_test)
# Out:
# Training Completed.

# %% [markdown]
# ### Comparing the predicted and actual flower classification

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred}) 
df
# Out:
#     Actual  Predicted
# 0        0          0
# 1        1          1
# 2        1          1
# 3        0          0
# 4        2          2
# 5        1          1
# 6        2          2
# 7        0          0
# 8        0          0
# 9        2          2
# 10       1          1
# 11       0          0
# 12       2          2
# 13       1          1
# 14       1          1

# %% [markdown]
# ### Visualizing the Trained Model

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
#Visualizing the trained Decision Tree Classifier taking all 4 features in consideration

export_graphviz(
        tree_classifier,
        out_file="img\desision_tree.dot",
        feature_names=iris.feature_names[:],
        class_names=iris.target_names,
        rounded=True,
        filled=True
)

(graph,) = pydot.graph_from_dot_file('img\desision_tree.dot')
graph.write_png('img\desision_tree.png')

Image(filename='img\desision_tree.png')

# %% [markdown]
# ### Predicting the class output of some random variable
#  - Petal length and width
#  - Sepal length and width

# %%
print("Class Names = ",iris.target_names)

# Estimating class probabilities
print()
print("Estimating Class Probabilities for flower whose petals length width are 4.7cm and 3.2cm and sepal length and width are 1.3cm and 0.2cm. ")
print()
print('Output = ',tree_classifier.predict([[4.7, 3.2, 1.3, 0.2]]))
print()
print("Our model predicts the class as 0, that is, setosa.")
# Out:
# Class Names =  ['setosa' 'versicolor' 'virginica']
#
# Estimating Class Probabilities for flower whose petals length width are 4.7cm and 3.2cm and sepal length and width are 1.3cm and 0.2cm.
#
# Output =  [0]
#
# Our model predicts the class as 0, that is, setosa.

# %% [markdown]
# ### Calculating the Model Accuracy

# %%
# Model Accuracy
print("Accuracy:",sm.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
#  - Since all the four features have taken into account, the accuracy of this model is 1 or 100%.

# %% [markdown]
# ### Conclusion
#
#  - Prediction using the Decision Tree Model was carried out successfully to evaluate the model accuracy value.
